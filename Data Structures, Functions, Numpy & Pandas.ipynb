# %% [raw]
# 1) Create a list of 5 integers. Perform and print the result of the following operations: append, extend, insert, remove, pop, clear, index, count, sort, and reverse.

# %%
a=[11,4,56,3,12]
a.append(31)

# %%
a
# Out:
# [11, 4, 56, 3, 12, 31]

# %%
a.extend([22])
a
# Out:
# [11, 4, 56, 3, 12, 31, 22]

# %%
a.insert(2,35)
a
# Out:
# [11, 4, 35, 56, 3, 12, 31, 22]

# %%
a.remove(3)

# %%
a
# Out:
# [11, 4, 35, 56, 12, 31, 22]

# %%
a.pop(2)
# Out:
# 35

# %%
a
# Out:
# [11, 4, 56, 12, 31, 22]

# %%
a.index(56)
# Out:
# 2

# %%
a.append(56)

# %%
a.count(56)
# Out:
# 2

# %%
a.sort()
a
# Out:
# [4, 11, 12, 22, 31, 56, 56]

# %%
a.reverse()
a
# Out:
# [56, 56, 31, 22, 12, 11, 4]

# %%
a.clear()

# %%
a
# Out:
# []

# %% [raw]
# 2) Create a tuple that stores 3 student names. Try changing the second name in the tuple. What happens? Explain why.

# %%
stu_names=("sriram","sachin","gopal")
stu_names[1]="abishek"
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[16], line 2
#       1 stu_names=("sriram","sachin","gopal")
# ----> 2 stu_names[1]="abishek"
#
# TypeError: 'tuple' object does not support item assignment

# %% [raw]
# Because the tuple is immutable,once creating tuple it cannot be changed or modified,the tuple is fixed

# %% [raw]
# 3) Create a set of integers with some duplicate values. Print the set and explain the output.

# %%
a=[56, 56, 31, 22, 12, 11, 4]
a_set=set(a)

# %%
a_set
# Out:
# {4, 11, 12, 22, 31, 56}

# %% [raw]
# it dosent contain any duplicate value because set dont allow any duplicates value

# %% [raw]
# 4) Create a dictionary with the keys: 'name', 'age', and 'city'. Update the age and add a new key 'email'. Print the final dictionary

# %%
dict_1={"name":"sriram","age":23,"city":"Bangalore"}

# %%
dict_1
# Out:
# {'name': 'sriram', 'age': 23, 'city': 'Bangalore'}

# %%
dict_1["age"]=22

dict_1["email"]="Sriramsv7@gmail.com"

# %%
dict_1
# Out:
# {'name': 'sriram',
#  'age': 22,
#  'city': 'Bangalore',
#  'email': 'Sriramsv7@gmail.com'}

# %% [raw]
# 5) Write a script that checks if a person is eligible to vote (age ≥ 18). Take age as a variable and print the appropriate message.

# %%
age=int(input("enter the age: "))
if age>=18:
    print("eligible to vote")
else:
    print("not eligible")
# Out:
# enter the age:  19
# eligible to vote

# %% [raw]
# 6) Given a 'marks' variable, print the grade:- 90 and above: 'A'- 75–89: 'B'- 50–74: 'C'- Below 50: 'Fail'

# %%
mark=int(input("enter the mark: "))

if mark >= 90:
    print("A")
elif mark >=75:
    print("B")
elif mark >=50:
    print("C")
else:
    print("Fail")
# Out:
# enter the mark:  65
# C

# %% [raw]
# 7) Given a number, check if it's positive, and if it is also even. If not positive, print if it's zero or negative.

# %%
a=int(input("enter the number: "))

if a>0:
    if a%2==0:
        print("number is positive and even number")
    else:
        print("number is positive and odd number")

elif a==0:
    print("number is zero")
else:
    print("number is negative")
# Out:
# enter the number:  56
# number is positive and even number

# %% [markdown]
# ### Section B: Numpy

# %% [raw]
# 8) Create:- A scalar using np.array(5)- A 1D array with values 1 to 5- A 2D array (2x3) with values from 10 to 60 in steps of 10

# %%
import numpy as np

# %%
np.array(5)
# Out:
# array(5)

# %%
np.arange(1,6)
# Out:
# array([1, 2, 3, 4, 5])

# %%
np.arange(10, 61, 10).reshape(2, 3)
# Out:
# array([[10, 20, 30],
#        [40, 50, 60]])

# %%
9) Generate a 4x4 Numpy array of random integers between 0 and 100 using np.random.randint().

# %%
import numpy as np

random_array = np.random.randint(0,101,size=(4,4))

print(random_array)
# Out:
# [[97 33 16  7]
#  [ 3 96 21 90]
#  [58 36 64 57]
#  [31 62 92 69]]

# %%
import pandas as pd

# %% [raw]
# 10) Create a 2D numpy array of shape (3x3). Convert it into a pandas DataFrame and add column names: 'A', 'B', 'C'.

# %%
array=np.arange(10, 61, 10).reshape(2, 3)

# %%
array
# Out:
# array([[10, 20, 30],
#        [40, 50, 60]])

# %%
column_names = ['A', 'B', 'C']
df = pd.DataFrame(data=array, columns=column_names)

# %%
df
# Out:
#     A   B   C
# 0  10  20  30
# 1  40  50  60

# %% [raw]
# Create a small DataFrame manually with 10 rows and columns: 'Name', 'Age', 'City', and 'Salary'. Then:- Use .info(), .describe()- Select 'Name' and 'City' columns- Drop 'City' column- Fill any missing values in 'Salary' column with the mean- Remove any duplicate rows

# %%
data = {
    'Name': ['Sriram', 'Ravi', 'Sachin', 'Mohan', 'Gopal', 'Rajesh', 'Abishek', 'Vikas', 'RaviKumar', 'Priyan'],
    'Age': [28, 32, 25, 45, 30, 38, 27, 28, 32, 28],
    'City': ['Mumbai', 'Delhi', 'Bengaluru', 'Chennai', 'Hyderabad', 'Delhi', 'Mumbai', 'Bengaluru', 'Delhi', 'Mumbai'],
    'Salary': [600000, 950000, 80000, np.nan, 700000, 1500000, 750000, np.nan, 950000, 600000]
}

# %%
df=pd.DataFrame(data=data)

# %%
df
# Out:
#         Name  Age       City     Salary
# 0     Sriram   28     Mumbai   600000.0
# 1       Ravi   32      Delhi   950000.0
# 2     Sachin   25  Bengaluru    80000.0
# 3      Mohan   45    Chennai        NaN
# 4      Gopal   30  Hyderabad   700000.0
# 5     Rajesh   38      Delhi  1500000.0
# 6    Abishek   27     Mumbai   750000.0
# 7      Vikas   28  Bengaluru        NaN
# 8  RaviKumar   32      Delhi   950000.0
# 9     Priyan   28     Mumbai   600000.0

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10 entries, 0 to 9
# Data columns (total 4 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   Name    10 non-null     object
#  1   Age     10 non-null     int64
#  2   City    10 non-null     object
#  3   Salary  8 non-null      float64
# dtypes: float64(1), int64(1), object(2)
# memory usage: 452.0+ bytes

# %%
df.describe()
# Out:
#              Age        Salary
# count  10.000000  8.000000e+00
# mean   31.300000  7.662500e+05
# std     6.019413  4.029866e+05
# min    25.000000  8.000000e+04
# 25%    28.000000  6.000000e+05
# 50%    29.000000  7.250000e+05
# 75%    32.000000  9.500000e+05
# max    45.000000  1.500000e+06

# %%
df[['Name', 'City']]
# Out:
#         Name       City
# 0     Sriram     Mumbai
# 1       Ravi      Delhi
# 2     Sachin  Bengaluru
# 3      Mohan    Chennai
# 4      Gopal  Hyderabad
# 5     Rajesh      Delhi
# 6    Abishek     Mumbai
# 7      Vikas  Bengaluru
# 8  RaviKumar      Delhi
# 9     Priyan     Mumbai

# %%
df=df.drop(columns=['City'])

# %%
df
# Out:
#         Name  Age     Salary
# 0     Sriram   28   600000.0
# 1       Ravi   32   950000.0
# 2     Sachin   25    80000.0
# 3      Mohan   45        NaN
# 4      Gopal   30   700000.0
# 5     Rajesh   38  1500000.0
# 6    Abishek   27   750000.0
# 7      Vikas   28        NaN
# 8  RaviKumar   32   950000.0
# 9     Priyan   28   600000.0

# %%
mean_salary=df["Salary"].mean()
mean_salary
df["Salary"]=df["Salary"].fillna(mean_salary)

# %%
df
# Out:
#         Name  Age     Salary
# 0     Sriram   28   600000.0
# 1       Ravi   32   950000.0
# 2     Sachin   25    80000.0
# 3      Mohan   45   766250.0
# 4      Gopal   30   700000.0
# 5     Rajesh   38  1500000.0
# 6    Abishek   27   750000.0
# 7      Vikas   28   766250.0
# 8  RaviKumar   32   950000.0
# 9     Priyan   28   600000.0

# %%
df.duplicated().sum()
# Out:
# 0
